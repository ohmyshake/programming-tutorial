# %% [markdown]
# # sac

# %% [markdown]
# - Author: *{{Fu}}*
# - Update: *July 29, 2022*
# - Reading: *30 min*
#
# ---

# %%
import numpy as np
import matplotlib.pyplot as plt
plt.ion()

data = np.random.randn(2, 100)
fig, ax = plt.subplots()
ax.scatter(*data, c=data[1], s=100*np.abs(data[0]));

# %% [markdown]
# ```{tip}
# If you'd like to execute code that is in your Markdown files, you can use the {code-cell} directive in MyST Markdown. See for more information.
# ```

# %% [markdown]
# ````{toggle}
# ```python
# import numpy
# cd skdkdd
# ```
# ````

# %% [markdown]
# ## Manual

# %% [markdown]
# ### read data

# %%
# !sac '\n' quit
# Out:
#  SEISMIC ANALYSIS CODE [07/17/2022 (Version 102.0)]
#  Copyright 1995 Regents of the University of California
#
#  ERROR  108: File does not exist: \n
# SAC>

# %% [markdown]
# ### write data

# %% [markdown]
# ### head parameter

# %% [markdown]
# ### filter

# %% [markdown]
# ### remove instrument response

# %% [markdown]
# ### rotate

# %% [markdown]
# ### resample

# %% [markdown]
# ### ppk pick

# %% [markdown]
# ## Script

# %% [markdown]
# ### bash

# %% [markdown]
# ### python

# %% [markdown]
# ```{code-cell} ipython3
# :tags: [hide-input,hide-output,output_scroll,remove-stderr,raises-exception]
#
# os.putenv("SAC_DISPLAY_COPYRIGHT", '0')
#
# ```
